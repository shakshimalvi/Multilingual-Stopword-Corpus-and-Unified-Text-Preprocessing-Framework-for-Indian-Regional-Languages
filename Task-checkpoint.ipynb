# %%
import sys
sys.path.append(r"C:\Users\hp\OneDrive\Desktop\Data Science by Shakshi\Innomatics Research Lab\Machine Learning")

# %%
from smartprep.text import data_prepare

# %%
print(data_prepare("This is a test sentence"))
# Out:
# test sentence

# %%
text = "This is a very important Machine Learning concept!"
cleaned = data_prepare(
    text,
    custom_stopwords={"very", "important"}
)
print(cleaned)
# Out:
# machine learn concept

# %%
text1 = "यह एक बहुत अच्छा Machine Learning example है"
text2 = "मुझे Data Science सीखना बहुत पसंद है और यह useful है"

# %%
text3 = "இது ஒரு நல்ல machine learning example ஆகும்"
text4 = "Data Science மிகவும் useful மற்றும் interesting உள்ளது"

# %%
text5 = "ಇದು ಒಂದು machine learning ಉದಾಹರಣೆ ಆಗಿದೆ"
text6 = "Data Science ಬಹಳ interesting ಮತ್ತು ಉಪಯುಕ್ತವಾಗಿದೆ"

# %%
text7 = "यह machine learning model மிகவும் useful ಮತ್ತು अच्छा है"
text8 = "Data Science सीखना மிகவும் interesting ಮತ್ತು उपयोगी है"

# %%
text9 = "!!! This is AMAZING!!! यह बहुत अच्छा है 123 ###"
text10 = "Machine Learning @2026 மிகவும் powerful!!! $$$"

# %%
texts = [text1, text2, text3, text4, text5, text6, text7, text8, text9, text10]
for t in texts:
    print("Original:", t)
    print("Cleaned :", data_prepare(t))
    print("-" * 50)
# Out:
# Original: यह एक बहुत अच्छा Machine Learning example है
# Cleaned : एक अच्छा machine learn example
# --------------------------------------------------
# Original: मुझे Data Science सीखना बहुत पसंद है और यह useful है
# Cleaned : मुझे data science सीखना पसंद useful
# --------------------------------------------------
# Original: இது ஒரு நல்ல machine learning example ஆகும்
# Cleaned : நல்ல machine learn example ஆகும்
# --------------------------------------------------
# Original: Data Science மிகவும் useful மற்றும் interesting உள்ளது
# Cleaned : data science மிகவும் useful interest உள்ளது
# --------------------------------------------------
# Original: ಇದು ಒಂದು machine learning ಉದಾಹರಣೆ ಆಗಿದೆ
# Cleaned : machine learn ಉದಾಹರಣೆ ಆಗಿದೆ
# --------------------------------------------------
# Original: Data Science ಬಹಳ interesting ಮತ್ತು ಉಪಯುಕ್ತವಾಗಿದೆ
# Cleaned : data science ಬಹಳ interest ಉಪಯುಕ್ತವಾಗಿದೆ
# --------------------------------------------------
# ...
